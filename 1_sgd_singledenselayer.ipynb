# %% [markdown]
# <a href="https://colab.research.google.com/github/yiyichanmyae/tensorflow/blob/master/1_sgd_singledenselayer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Train and Test the model pattern of
#
# y = (x * 2) -1
#
# -   single dense layer
# -   Sequential Model
# -   SGD optimizer
# -   mean_squared_error
#
#
# Check the learned weights of the model

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# create model
l0 = Dense(units=1, input_shape=[1])
model = Sequential(l0)

# compile model
model.compile(optimizer="sgd", loss="mean_squared_error")

# data and labels
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# train model
model.fit(xs, ys, epochs=500)

# predict test data
print(model.predict([10.0]))
print(" here is what I learned: {}".format(l0.get_weights()))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 303ms/step - loss: 55.5254
# Epoch 2/500
# 1/1 [==============================] - 0s 10ms/step - loss: 44.0995
# Epoch 3/500
# 1/1 [==============================] - 0s 8ms/step - loss: 35.1016
# Epoch 4/500
# 1/1 [==============================] - 0s 11ms/step - loss: 28.0142
# Epoch 5/500
# 1/1 [==============================] - 0s 11ms/step - loss: 22.4300
# Epoch 6/500
# 1/1 [==============================] - 0s 9ms/step - loss: 18.0286
# Epoch 7/500
# 1/1 [==============================] - 0s 10ms/step - loss: 14.5579
# Epoch 8/500
# 1/1 [==============================] - 0s 10ms/step - loss: 11.8197
# Epoch 9/500
# 1/1 [==============================] - 0s 11ms/step - loss: 9.6579
# Epoch 10/500
# 1/1 [==============================] - 0s 9ms/step - loss: 7.9497
# Epoch 11/500
# 1/1 [==============================] - 0s 8ms/step - loss: 6.5985
# Epoch 12/500
# ...
